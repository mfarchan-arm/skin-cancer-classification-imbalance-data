# %%
import seaborn as sns
import matplotlib.pyplot as plt
from imblearn.over_sampling import RandomOverSampler 
import numpy as np
from sklearn.model_selection import train_test_split
import os, cv2
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Flatten, Dense, MaxPool2D
import pandas as pd
from imblearn.combine import SMOTEENN
import time

# %%
data_dir = r'D:\Kuliah\Semester 7\PCD\New\dataset\hmnist_28_28_RGB.csv'
data = pd.read_csv(data_dir)
data.head()
# Out:
#    pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005  \
# 0        192        153        193        195        155        192
# 1         25         14         30         68         48         75
# 2        192        138        153        200        145        163
# 3         38         19         30         95         59         72
# 4        158        113        139        194        144        174
#
#    pixel0006  pixel0007  pixel0008  pixel0009  ...  pixel2343  pixel2344  \
# 0        197        154        185        202  ...        173        124
# 1        123         93        126        158  ...         60         39
# 2        201        142        160        206  ...        167        129
# 3        143        103        119        171  ...         44         26
# 4        215        162        191        225  ...        209        166
#
#    pixel2345  pixel2346  pixel2347  pixel2348  pixel2349  pixel2350  \
# 0        138        183        147        166        185        154
# 1         55         25         14         28         25         14
# 2        143        159        124        142        136        104
# 3         36         25         12         17         25         12
# 4        185        172        135        149        109         78
#
#    pixel2351  label
# 0        177      2
# 1         27      2
# 2        117      2
# 3         15      2
# 4         92      2
#
# [5 rows x 2353 columns]

# %%
y = data['label']
x = data.drop(columns = ['label'])

# %%
oversample = RandomOverSampler()
x,y  = oversample.fit_resample(x,y)

# %%
x = np.array(x).reshape(-1,28,28,3)
print('Shape of X :',x.shape)
# Out:
# Shape of X : (46935, 28, 28, 3)

# %%
unique_classes, class_counts = np.unique(y, return_counts=True)
for cls, count in zip(unique_classes, class_counts):
    print(f"Kelas {cls}: {count} sampel")
# Out:
# Kelas 0: 6705 sampel
# Kelas 1: 6705 sampel
# Kelas 2: 6705 sampel
# Kelas 3: 6705 sampel
# Kelas 4: 6705 sampel
# Kelas 5: 6705 sampel
# Kelas 6: 6705 sampel

# %%
tabular_data = pd.read_csv(r'D:\Kuliah\Semester 7\PCD\New\dataset\HAM10000_metadata.csv')
tabular_data.head()
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear

# %%
classes = {4: ('nv', ' melanocytic nevi'), 
           6: ('mel', 'melanoma'), 
           2 :('bkl', 'benign keratosis-like lesions'), 
           1:('bcc' , ' basal cell carcinoma'), 
           5: ('vasc', ' pyogenic granulomas and hemorrhage'), 
           0: ('akiec', 'Actinic keratoses and intraepithelial carcinomae'),  
           3: ('df', 'dermatofibroma')}

# %%
t = np.zeros([46935, 32, 32, 3],dtype=np.float32)
print(t.shape)
# Out:
# (46935, 32, 32, 3)

# %%
import scipy.ndimage

# %%
for i in range(46935):
    t[i] = scipy.ndimage.zoom(x[i],32/28)

# %%
x = np.array(t).reshape(-1,32,32,3)
print('Shape of X :',x.shape)
# Out:
# Shape of X : (46935, 32, 32, 3)

# %%
"""Standardization and Splitting Data"""

x = (x-np.mean(x))/np.std(x)
X_train, X_test, Y_train, Y_test = train_test_split(x,y, test_size=0.2, random_state=1)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

class_counts = y.value_counts().sort_index()
ax1.bar(class_counts.index, class_counts.values, color='skyblue')
ax1.set_xlabel('Kelas')
ax1.set_ylabel('Jumlah')
ax1.set_title('Data Train')

class_counts_oversample = y.value_counts().sort_index()
ax2.bar(class_counts_oversample.index, class_counts_oversample.values, color='skyblue')
ax2.set_xlabel('Kelas')
ax2.set_ylabel('Jumlah')
ax2.set_title('Data Test')

plt.tight_layout()
plt.show()

# %%
from keras.applications import ResNet50
base_model = ResNet50(input_shape=(32,32,3),weights='imagenet', include_top=False)

for layer in base_model.layers:
    layer.trainable = False

model = tf.keras.Sequential([
    base_model,
    Flatten(),
    Dense(64, activation='relu'),
    Dense(7, activation='softmax')
])
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 1, 1, 2048)        23587712
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 64)                131136
#
#  dense_1 (Dense)             (None, 7)                 455
#
# =================================================================
# Total params: 23719303 (90.48 MB)
# Trainable params: 131591 (514.03 KB)
# Non-trainable params: 23587712 (89.98 MB)
# _________________________________________________________________
# None

# %%
# Callback untuk menghentikan pelatihan jika validasi loss tidak berubah dalam beberapa epoch
early_stopping_callback = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',  # Monitor validasi loss
    patience=5,  # Jumlah epoch tanpa perubahan sebelum menghentikan pelatihan
    verbose=1,  # Menampilkan pesan ketika menghentikan pelatihan
    restore_best_weights=True  # Mengembalikan bobot terbaik saat menghentikan pelatihan
)

callback = tf.keras.callbacks.ModelCheckpoint(filepath='best_model_vgg.h5',
                                              monitor='val_loss',
                                              save_best_only=True,
                                              save_weights_only=False,
                                              mode='max',
                                              verbose=1)

# %%
model.compile(loss = 'sparse_categorical_crossentropy',
             optimizer = 'adam',
              metrics = ['accuracy'])
history = model.fit(X_train,
                    Y_train,
                    validation_split=0.2,
                    batch_size = 128,
                    epochs = 70,
                    callbacks=([callback], [early_stopping_callback]))
# Out:
# Epoch 1/70
# 235/235 [==============================] - ETA: 0s - loss: 1.5760 - accuracy: 0.3851
# Epoch 1: val_loss improved from -inf to 1.40048, saving model to best_model_vgg.h5
# C:\Users\Fenny Puspitasari\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\engine\training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 235/235 [==============================] - 54s 219ms/step - loss: 1.5760 - accuracy: 0.3851 - val_loss: 1.4005 - val_accuracy: 0.4704
# Epoch 2/70
# 235/235 [==============================] - ETA: 0s - loss: 1.3067 - accuracy: 0.5030
# Epoch 2: val_loss did not improve from 1.40048
# 235/235 [==============================] - 50s 212ms/step - loss: 1.3067 - accuracy: 0.5030 - val_loss: 1.2749 - val_accuracy: 0.5095
# Epoch 3/70
# 235/235 [==============================] - ETA: 0s - loss: 1.1871 - accuracy: 0.5523
# Epoch 3: val_loss did not improve from 1.40048
# 235/235 [==============================] - 50s 214ms/step - loss: 1.1871 - accuracy: 0.5523 - val_loss: 1.1281 - val_accuracy: 0.5889
# Epoch 4/70
# 235/235 [==============================] - ETA: 0s - loss: 1.0989 - accuracy: 0.5907
# Epoch 4: val_loss did not improve from 1.40048
# 235/235 [==============================] - 51s 219ms/step - loss: 1.0989 - accuracy: 0.5907 - val_loss: 1.0729 - val_accuracy: 0.5875
# Epoch 5/70
# 235/235 [==============================] - ETA: 0s - loss: 1.0336 - accuracy: 0.6153
# Epoch 5: val_loss did not improve from 1.40048
# 235/235 [==============================] - 51s 215ms/step - loss: 1.0336 - accuracy: 0.6153 - val_loss: 1.0339 - val_accuracy: 0.6095
# Epoch 6/70
# 235/235 [==============================] - ETA: 0s - loss: 0.9774 - accuracy: 0.6361
# Epoch 6: val_loss did not improve from 1.40048
# 235/235 [==============================] - 51s 218ms/step - loss: 0.9774 - accuracy: 0.6361 - val_loss: 0.9760 - val_accuracy: 0.6349
# Epoch 7/70
# 235/235 [==============================] - ETA: 0s - loss: 0.9237 - accuracy: 0.6572
# Epoch 7: val_loss did not improve from 1.40048
# 235/235 [==============================] - 51s
val_loss did not improve from 1.40048
# 235/235 [==============================] - 52s 223ms/step - loss: 0.4052 - accuracy: 0.8640 - val_loss: 0.4778 - val_accuracy: 0.8465
# Epoch 38/70
# 235/235 [==============================] - ETA: 0s - loss: 0.4064 - accuracy: 0.8600
# Epoch 38: val_loss did not improve from 1.40048
# 235/235 [==============================] - 52s 223ms/step - loss: 0.4064 - accuracy: 0.8600 - val_loss: 0.4661 - val_accuracy: 0.8494
# Epoch 39/70
# 235/235 [==============================] - ETA: 0s - loss: 0.3934 - accuracy: 0.8676
# Epoch 39: val_loss did not improve from 1.40048
# 235/235 [==============================] - 52s 222ms/step - loss: 0.3934 - accuracy: 0.8676 - val_loss: 0.4729 - val_accuracy: 0.8372
# Epoch 40/70
# 235/235 [==============================] - ETA: 0s - loss: 0.3905 - accuracy: 0.8675
# Epoch 40: val_loss did not improve from 1.40048
# 235/235 [==============================] - 53s 225ms/step - loss: 0.3905 - accuracy: 0.8675 - val_loss: 0.5180 - val_accuracy: 0.8234
# Epoch 41/70
# 235/235 [==============================] - ETA: 0s - loss: 0.3848 - accuracy: 0.8692
# Epoch 41: val_loss did not improve from 1.40048
# 235/235 [==============================] - 53s 224ms/step - loss: 0.3848 - accuracy: 0.8692 - val_loss: 0.5021 - val_accuracy: 0.8305
# Epoch 42/70
# 235/235 [==============================] - ETA: 0s - loss: 0.3754 - accuracy: 0.8741
# Epoch 42: val_loss did not improve from 1.40048
# 235/235 [==============================] - 54s 229ms/step - loss: 0.3754 - accuracy: 0.8741 - val_loss: 0.4537 - val_accuracy: 0.8523
# Epoch 43/70
# 235/235 [==============================] - ETA: 0s - loss: 0.3690 - accuracy: 0.8772
# Epoch 43: val_loss did not improve from 1.40048
# 235/235 [==============================] - 52s 221ms/step - loss: 0.3690 - accuracy: 0.8772 - val_loss: 0.4511 - val_accuracy: 0.8514
# Epoch 44/70
# 235/235 [==============================] - ETA: 0s - loss: 0.3537 - accuracy: 0.8821
# Epoch 44: val_loss did not improve from 1.40048
# 235/235 [==============================] - 52s 221ms/step - loss: 0.3537 - accuracy: 0.8821 - val_loss: 0.4588 - val_accuracy: 0.8499
# Epoch 45/70
# 235/235 [==============================] - ETA: 0s - loss: 0.3610 - accuracy: 0.8771
# Epoch 45: val_loss did not improve from 1.40048
# 235/235 [==============================] - 52s 221ms/step - loss: 0.3610 - accuracy: 0.8771 - val_loss: 0.4536 - val_accuracy: 0.8619
# Epoch 46/70
# 235/235 [==============================] - ETA: 0s - loss: 0.3375 - accuracy: 0.8895
# Epoch 46: val_loss did not improve from 1.40048
# 235/235 [==============================] - 52s 221ms/step - loss: 0.3375 - accuracy: 0.8895 - val_loss: 0.4463 - val_accuracy: 0.8562
# Epoch 47/70
# 235/235 [==============================] - ETA: 0s - loss: 0.3442 - accuracy: 0.8847
# Epoch 47: val_loss did not improve from 1.40048
# 235/235 [==============================] - 52s 223ms/step - loss: 0.3442 - accuracy: 0.8847 - val_loss: 0.4347 - val_accuracy: 0.8635
# Epoch 48/70
# 235/235 [==============================] - ETA: 0s - loss: 0.3350 - accuracy: 0.8890
# Epoch 48: val_loss did not improve from 1.40048
# 235/235 [==============================] - 52s 220ms/step - loss: 0.3350 - accuracy: 0.8890 - val_loss: 0.4622 - val_accuracy: 0.8490
# Epoch 49/70
# 235/235 [==============================] - ETA: 0s - loss: 0.3283 - accuracy: 0.8914
# Epoch 49: val_loss did not improve from 1.40048
# 235/235 [==============================] - 52s 221ms/step - loss: 0.3283 - accuracy: 0.8914 - val_loss: 0.4608 - val_accuracy: 0.8497
# Epoch 50/70
# 235/235 [==============================] - ETA: 0s - loss: 0.3302 - accuracy: 0.8900
# Epoch 50: val_loss did not improve from 1.40048
# 235/235 [==============================] - 52s 221ms/step - loss: 0.3302 - accuracy: 0.8900 - val_loss: 0.4071 - val_accuracy: 0.8726
# Epoch 51/70
# 235/235 [==============================] - ETA: 0s - loss: 0.3227 - accuracy: 0.8939
# Epoch 51: val_loss did not improve from 1.40048
# 235/235 [==============================] - 52s 222ms/step - loss: 0.3227 - accuracy: 0.8939 - val_loss: 0.4839 - val_accuracy: 0.8257
# Epoch 52/70
# 235/235 [==============================] - ETA: 0s - loss: 0.3243 - accuracy: 0.8923
# Epoch 52: val_loss did not improve from 1.40048
# 235/235 [==============================] - 53s 225ms/step - loss: 0.3243 - accuracy: 0.8923 - val_loss: 0.4014 - val_accuracy: 0.8740
# Epoch 53/70
# 235/235 [==============================] - ETA: 0s - loss: 0.3003 - accuracy: 0.9049
# Epoch 53: val_loss did not improve from 1.40048
# 235/235 [==============================] - 52s 221ms/step - loss: 0.3003 - accuracy: 0.9049 - val_loss: 0.4027 - val_accuracy: 0.8691
# Epoch 54/70
# 235/235 [==============================] - ETA: 0s - loss: 0.2997 - accuracy: 0.9016
# Epoch 54: val_loss did not improve from 1.40048
# 235/235 [==============================] - 52s 221ms/step - loss: 0.2997 - accuracy: 0.9016 - val_loss: 0.4137 - val_accuracy: 0.8719
# Epoch 55/70
# 235/235 [==============================] - ETA: 0s - loss: 0.3011 - accuracy: 0.9024
# Epoch 55: val_loss did not improve from 1.40048
# 235/235 [==============================] - 52s 221ms/step - loss: 0.3011 - accuracy: 0.9024 - val_loss: 0.3992 - val_accuracy: 0.8727
# Epoch 56/70
# 235/235 [==============================] - ETA: 0s - loss: 0.2995 - accuracy: 0.9005
# Epoch 56: val_loss did not improve from 1.40048
# 235/235 [==============================] - 53s 224ms/step - loss: 0.2995 - accuracy: 0.9005 - val_loss: 0.4068 - val_accuracy: 0.8642
# Epoch 57/70
# 235/235 [==============================] - ETA: 0s - loss: 0.2871 - accuracy: 0.9065
# Epoch 57: val_loss did not improve from 1.40048
# 235/235 [==============================] - 52s 222ms/step - loss: 0.2871 - accuracy: 0.9065 - val_loss: 0.3693 - val_accuracy: 0.8883
# Epoch 58/70
# 235/235 [==============================] - ETA: 0s - loss: 0.2771 - accuracy: 0.9125
# Epoch 58: val_loss did not improve from 1.40048
# 235/235 [==============================] - 52s 222ms/step - loss: 0.2771 - accuracy: 0.9125 - val_loss: 0.3746 - val_accuracy: 0.8879
# Epoch 59/70
# 235/235 [==============================] - ETA: 0s - loss: 0.2702 - accuracy: 0.9151
# Epoch 59: val_loss did not improve from 1.40048
# 235/235 [==============================] - 52s 221ms/step - loss: 0.2702 - accuracy: 0.9151 - val_loss: 0.4011 - val_accuracy: 0.8711
# Epoch 60/70
# 235/235 [==============================] - ETA: 0s - loss: 0.2735 - accuracy: 0.9127
# Epoch 60: val_loss did not improve from 1.40048
# 235/235 [==============================] - 52s 221ms/step - loss: 0.2735 - accuracy: 0.9127 - val_loss: 0.4181 - val_accuracy: 0.8800
# Epoch 61/70
# 235/235 [==============================] - ETA: 0s - loss: 0.2730 - accuracy: 0.9124
# Epoch 61: val_loss did not improve from 1.40048
# 235/235 [==============================] - 52s 222ms/step - loss: 0.2730 - accuracy: 0.9124 - val_loss: 0.3989 - val_accuracy: 0.8766
# Epoch 62/70
# 235/235 [==============================] - ETA: 0s - loss: 0.2676 - accuracy: 0.9140
# Epoch 62: val_loss did not improve from 1.40048
# Restoring model weights from the end of the best epoch: 57.
# 235/235 [==============================] - 52s 223ms/step - loss: 0.2676 - accuracy: 0.9140 - val_loss: 0.3901 - val_accuracy: 0.8842
# Epoch 62: early stopping

# %%
def plot_training(hist):
    tr_acc = hist.history['accuracy']
    tr_loss = hist.history['loss']
    val_acc = hist.history['val_accuracy']
    val_loss = hist.history['val_loss']
    index_loss = np.argmin(val_loss)
    val_lowest = val_loss[index_loss]
    index_acc = np.argmax(val_acc)
    acc_highest = val_acc[index_acc]

    plt.figure(figsize= (16, 4))
    plt.style.use('fivethirtyeight')
    Epochs = [i+1 for i in range(len(tr_acc))]
    loss_label = f'best epoch= {str(index_loss + 1)}'
    acc_label = f'best epoch= {str(index_acc + 1)}'
    
    plt.subplot(1, 2, 1)
    plt.plot(Epochs, tr_loss, label= 'Training loss')
    plt.plot(Epochs, val_loss, label= 'Validation loss')
    plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    
    plt.subplot(1, 2, 2)
    plt.plot(Epochs, tr_acc,  label= 'Training Accuracy')
    plt.plot(Epochs, val_acc,  label= 'Validation Accuracy')
    plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    
    plt.tight_layout
    plt.show()

# %%
plot_training(history)

# %%
train_score = model.evaluate(X_train, Y_train, verbose= 1)
test_score = model.evaluate(X_test, Y_test, verbose= 1)

print("Train Loss: ", train_score[0])
print("Train Accuracy: ", train_score[1])
print('-' * 20)
print("Test Loss: ", test_score[0])
print("Test Accuracy: ", test_score[1])
# Out:
# 1174/1174 [==============================] - 71s 60ms/step - loss: 0.2788 - accuracy: 0.9171
# 294/294 [==============================] - 18s 61ms/step - loss: 0.3615 - accuracy: 0.8969
# Train Loss:  0.27882668375968933
# Train Accuracy:  0.9170661568641663
# --------------------
# Test Loss:  0.3614787459373474
# Test Accuracy:  0.8968786597251892

# %%
y_pred = model.predict(X_test)
# Out:
# 294/294 [==============================] - 19s 60ms/step

# %%
y_pred = np.argmax(y_pred, axis=1)

# %%
y_true = Y_test.to_numpy()

# %%
from sklearn.metrics import accuracy_score, classification_report

# Assuming y_true is a NumPy array or a list and y_pred is a NumPy array
accuracy = accuracy_score(y_true, y_pred)
report = classification_report(y_true, y_pred)

# %%
print("Accuracy:", accuracy)
print("Classification Report:\n", report)
# Out:
# Accuracy: 0.8968786619793331
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.98      0.95      1359
#            1       0.94      0.86      0.90      1318
#            2       0.78      0.83      0.81      1262
#            3       0.96      1.00      0.98      1351
#            4       0.84      0.73      0.78      1374
#            5       0.98      1.00      0.99      1358
#            6       0.86      0.87      0.87      1365
#
#     accuracy                           0.90      9387
#    macro avg       0.90      0.90      0.89      9387
# weighted avg       0.90      0.90      0.90      9387

# %%
classes_labels = []
for key in classes.keys():
    classes_labels.append(key)

# %%
from sklearn.metrics import confusion_matrix
import itertools

# %%
# Confusion matrix
cm = cm = confusion_matrix(y_true, y_pred, labels=classes_labels)

plt.figure(figsize=(20,20))
plt.imshow(cm, interpolation= 'nearest', cmap= plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()

tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation= 45)
plt.yticks(tick_marks, classes)


thresh = cm.max() / 2.
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, cm[i, j], horizontalalignment= 'center', color= 'white' if cm[i, j] > thresh else 'black', fontsize=24)

plt.tight_layout()
plt.ylabel('True Label')
plt.xlabel('Predicted Label')

plt.show()

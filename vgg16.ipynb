# %%
import seaborn as sns
import matplotlib.pyplot as plt
from imblearn.over_sampling import RandomOverSampler 
import numpy as np
from sklearn.model_selection import train_test_split
import os, cv2
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Flatten, Dense, MaxPool2D
import pandas as pd
from imblearn.combine import SMOTEENN
import time

# %%
data_dir = r'D:\Kuliah\Semester 7\PCD\New\dataset\hmnist_28_28_RGB.csv'
data = pd.read_csv(data_dir)
data.head()
# Out:
#    pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005  \
# 0        192        153        193        195        155        192
# 1         25         14         30         68         48         75
# 2        192        138        153        200        145        163
# 3         38         19         30         95         59         72
# 4        158        113        139        194        144        174
#
#    pixel0006  pixel0007  pixel0008  pixel0009  ...  pixel2343  pixel2344  \
# 0        197        154        185        202  ...        173        124
# 1        123         93        126        158  ...         60         39
# 2        201        142        160        206  ...        167        129
# 3        143        103        119        171  ...         44         26
# 4        215        162        191        225  ...        209        166
#
#    pixel2345  pixel2346  pixel2347  pixel2348  pixel2349  pixel2350  \
# 0        138        183        147        166        185        154
# 1         55         25         14         28         25         14
# 2        143        159        124        142        136        104
# 3         36         25         12         17         25         12
# 4        185        172        135        149        109         78
#
#    pixel2351  label
# 0        177      2
# 1         27      2
# 2        117      2
# 3         15      2
# 4         92      2
#
# [5 rows x 2353 columns]

# %%
y = data['label']
x = data.drop(columns = ['label'])

# %%
oversample = RandomOverSampler()
x,y  = oversample.fit_resample(x,y)

# %%
x = np.array(x).reshape(-1,28,28,3)
print('Shape of X :',x.shape)
# Out:
# Shape of X : (46935, 28, 28, 3)

# %%
unique_classes, class_counts = np.unique(y, return_counts=True)
for cls, count in zip(unique_classes, class_counts):
    print(f"Kelas {cls}: {count} sampel")
# Out:
# Kelas 0: 6705 sampel
# Kelas 1: 6705 sampel
# Kelas 2: 6705 sampel
# Kelas 3: 6705 sampel
# Kelas 4: 6705 sampel
# Kelas 5: 6705 sampel
# Kelas 6: 6705 sampel

# %%
tabular_data = pd.read_csv(r'D:\Kuliah\Semester 7\PCD\New\dataset\HAM10000_metadata.csv')
tabular_data.head()
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear

# %%
classes = {4: ('nv', ' melanocytic nevi'), 
           6: ('mel', 'melanoma'), 
           2 :('bkl', 'benign keratosis-like lesions'), 
           1:('bcc' , ' basal cell carcinoma'), 
           5: ('vasc', ' pyogenic granulomas and hemorrhage'), 
           0: ('akiec', 'Actinic keratoses and intraepithelial carcinomae'),  
           3: ('df', 'dermatofibroma')}

# %%
t = np.zeros([46935, 32, 32, 3],dtype=np.float32)
print(t.shape)
# Out:
# (46935, 32, 32, 3)

# %%
import scipy.ndimage

# %%
for i in range(46935):
    t[i] = scipy.ndimage.zoom(x[i],32/28)

# %%
x = np.array(t).reshape(-1,32,32,3)
print('Shape of X :',x.shape)
# Out:
# Shape of X : (46935, 32, 32, 3)

# %%
"""Standardization and Splitting Data"""

x = (x-np.mean(x))/np.std(x)
X_train, X_test, Y_train, Y_test = train_test_split(x,y, test_size=0.2, random_state=1)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

class_counts = y.value_counts().sort_index()
ax1.bar(class_counts.index, class_counts.values, color='skyblue')
ax1.set_xlabel('Kelas')
ax1.set_ylabel('Jumlah')
ax1.set_title('Data Train')

class_counts_oversample = y.value_counts().sort_index()
ax2.bar(class_counts_oversample.index, class_counts_oversample.values, color='skyblue')
ax2.set_xlabel('Kelas')
ax2.set_ylabel('Jumlah')
ax2.set_title('Data Test')

plt.tight_layout()
plt.show()

# %%
from keras.applications import VGG16
base_model = VGG16(input_shape=(32,32,3),weights='imagenet', include_top=False)

for layer in base_model.layers:
    layer.trainable = False

model = tf.keras.Sequential([
    base_model,
    Flatten(),
    Dense(64, activation='relu'),
    Dense(7, activation='softmax')
])
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 1, 1, 512)         14714688
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 64)                32832
#
#  dense_1 (Dense)             (None, 7)                 455
#
# =================================================================
# Total params: 14747975 (56.26 MB)
# Trainable params: 33287 (130.03 KB)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________
# None

# %%
# Callback untuk menghentikan pelatihan jika validasi loss tidak berubah dalam beberapa epoch
early_stopping_callback = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',  # Monitor validasi loss
    patience=5,  # Jumlah epoch tanpa perubahan sebelum menghentikan pelatihan
    verbose=1,  # Menampilkan pesan ketika menghentikan pelatihan
    restore_best_weights=True  # Mengembalikan bobot terbaik saat menghentikan pelatihan
)

callback = tf.keras.callbacks.ModelCheckpoint(filepath='best_model_vgg.h5',
                                              monitor='val_loss',
                                              save_best_only=True,
                                              save_weights_only=False,
                                              mode='max',
                                              verbose=1)

# %%
model.compile(loss = 'sparse_categorical_crossentropy',
             optimizer = 'adam',
              metrics = ['accuracy'])
history = model.fit(X_train,
                    Y_train,
                    validation_split=0.2,
                    batch_size = 128,
                    epochs = 70,
                    callbacks=([callback], [early_stopping_callback]))
# Out:
# Epoch 1/70
# 235/235 [==============================] - ETA: 0s - loss: 1.2238 - accuracy: 0.5481
# Epoch 1: val_loss improved from -inf to 0.97499, saving model to best_model_vgg.h5
# 235/235 [==============================] - 86s 365ms/step - loss: 1.2238 - accuracy: 0.5481 - val_loss: 0.9750 - val_accuracy: 0.6479
# Epoch 2/70
# C:\Users\Fenny Puspitasari\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\engine\training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 235/235 [==============================] - ETA: 0s - loss: 0.8638 - accuracy: 0.6896
# Epoch 2: val_loss did not improve from 0.97499
# 235/235 [==============================] - 85s 362ms/step - loss: 0.8638 - accuracy: 0.6896 - val_loss: 0.7884 - val_accuracy: 0.7129
# Epoch 3/70
# 235/235 [==============================] - ETA: 0s - loss: 0.7167 - accuracy: 0.7476
# Epoch 3: val_loss did not improve from 0.97499
# 235/235 [==============================] - 87s 369ms/step - loss: 0.7167 - accuracy: 0.7476 - val_loss: 0.6827 - val_accuracy: 0.7607
# Epoch 4/70
# 235/235 [==============================] - ETA: 0s - loss: 0.6159 - accuracy: 0.7902
# Epoch 4: val_loss did not improve from 0.97499
# 235/235 [==============================] - 86s
70
# 235/235 [==============================] - ETA: 0s - loss: 0.1336 - accuracy: 0.9632
# Epoch 25: val_loss did not improve from 0.97499
# 235/235 [==============================] - 85s 363ms/step - loss: 0.1336 - accuracy: 0.9632 - val_loss: 0.2172 - val_accuracy: 0.9375
# Epoch 26/70
# 235/235 [==============================] - ETA: 0s - loss: 0.1267 - accuracy: 0.9652
# Epoch 26: val_loss did not improve from 0.97499
# 235/235 [==============================] - 85s 363ms/step - loss: 0.1267 - accuracy: 0.9652 - val_loss: 0.2131 - val_accuracy: 0.9370
# Epoch 27/70
# 235/235 [==============================] - ETA: 0s - loss: 0.1194 - accuracy: 0.9677
# Epoch 27: val_loss did not improve from 0.97499
# 235/235 [==============================] - 85s 361ms/step - loss: 0.1194 - accuracy: 0.9677 - val_loss: 0.2023 - val_accuracy: 0.9403
# Epoch 28/70
# 235/235 [==============================] - ETA: 0s - loss: 0.1154 - accuracy: 0.9683
# Epoch 28: val_loss did not improve from 0.97499
# 235/235 [==============================] - 86s 366ms/step - loss: 0.1154 - accuracy: 0.9683 - val_loss: 0.2081 - val_accuracy: 0.9417
# Epoch 29/70
# 235/235 [==============================] - ETA: 0s - loss: 0.1103 - accuracy: 0.9694
# Epoch 29: val_loss did not improve from 0.97499
# 235/235 [==============================] - 85s 363ms/step - loss: 0.1103 - accuracy: 0.9694 - val_loss: 0.1944 - val_accuracy: 0.9469
# Epoch 30/70
# 235/235 [==============================] - ETA: 0s - loss: 0.1045 - accuracy: 0.9720
# Epoch 30: val_loss did not improve from 0.97499
# 235/235 [==============================] - 85s 361ms/step - loss: 0.1045 - accuracy: 0.9720 - val_loss: 0.1853 - val_accuracy: 0.9486
# Epoch 31/70
# 235/235 [==============================] - ETA: 0s - loss: 0.1005 - accuracy: 0.9724
# Epoch 31: val_loss did not improve from 0.97499
# 235/235 [==============================] - 85s 363ms/step - loss: 0.1005 - accuracy: 0.9724 - val_loss: 0.1855 - val_accuracy: 0.9487
# Epoch 32/70
# 235/235 [==============================] - ETA: 0s - loss: 0.0939 - accuracy: 0.9752
# Epoch 32: val_loss did not improve from 0.97499
# 235/235 [==============================] - 86s 366ms/step - loss: 0.0939 - accuracy: 0.9752 - val_loss: 0.1803 - val_accuracy: 0.9531
# Epoch 33/70
# 235/235 [==============================] - ETA: 0s - loss: 0.0885 - accuracy: 0.9772
# Epoch 33: val_loss did not improve from 0.97499
# 235/235 [==============================] - 85s 361ms/step - loss: 0.0885 - accuracy: 0.9772 - val_loss: 0.1765 - val_accuracy: 0.9535
# Epoch 34/70
# 235/235 [==============================] - ETA: 0s - loss: 0.0866 - accuracy: 0.9770
# Epoch 34: val_loss did not improve from 0.97499
# 235/235 [==============================] - 85s 361ms/step - loss: 0.0866 - accuracy: 0.9770 - val_loss: 0.1826 - val_accuracy: 0.9523
# Epoch 35/70
# 235/235 [==============================] - ETA: 0s - loss: 0.0815 - accuracy: 0.9794
# Epoch 35: val_loss did not improve from 0.97499
# 235/235 [==============================] - 85s 363ms/step - loss: 0.0815 - accuracy: 0.9794 - val_loss: 0.1840 - val_accuracy: 0.9513
# Epoch 36/70
# 235/235 [==============================] - ETA: 0s - loss: 0.0768 - accuracy: 0.9803
# Epoch 36: val_loss did not improve from 0.97499
# 235/235 [==============================] - 85s 361ms/step - loss: 0.0768 - accuracy: 0.9803 - val_loss: 0.1855 - val_accuracy: 0.9535
# Epoch 37/70
# 235/235 [==============================] - ETA: 0s - loss: 0.0762 - accuracy: 0.9808
# Epoch 37: val_loss did not improve from 0.97499
# 235/235 [==============================] - 85s 361ms/step - loss: 0.0762 - accuracy: 0.9808 - val_loss: 0.1804 - val_accuracy: 0.9515
# Epoch 38/70
# 235/235 [==============================] - ETA: 0s - loss: 0.0723 - accuracy: 0.9810
# Epoch 38: val_loss did not improve from 0.97499
# Restoring model weights from the end of the best epoch: 33.
# 235/235 [==============================] - 85s 363ms/step - loss: 0.0723 - accuracy: 0.9810 - val_loss: 0.1799 - val_accuracy: 0.9565
# Epoch 38: early stopping

# %%
def plot_training(hist):
    tr_acc = hist.history['accuracy']
    tr_loss = hist.history['loss']
    val_acc = hist.history['val_accuracy']
    val_loss = hist.history['val_loss']
    index_loss = np.argmin(val_loss)
    val_lowest = val_loss[index_loss]
    index_acc = np.argmax(val_acc)
    acc_highest = val_acc[index_acc]

    plt.figure(figsize= (16, 4))
    plt.style.use('fivethirtyeight')
    Epochs = [i+1 for i in range(len(tr_acc))]
    loss_label = f'best epoch= {str(index_loss + 1)}'
    acc_label = f'best epoch= {str(index_acc + 1)}'
    
    plt.subplot(1, 2, 1)
    plt.plot(Epochs, tr_loss, label= 'Training loss')
    plt.plot(Epochs, val_loss, label= 'Validation loss')
    plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    
    plt.subplot(1, 2, 2)
    plt.plot(Epochs, tr_acc,  label= 'Training Accuracy')
    plt.plot(Epochs, val_acc,  label= 'Validation Accuracy')
    plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    
    plt.tight_layout
    plt.show()

# %%
plot_training(history)

# %%
train_score = model.evaluate(X_train, Y_train, verbose= 1)
test_score = model.evaluate(X_test, Y_test, verbose= 1)

print("Train Loss: ", train_score[0])
print("Train Accuracy: ", train_score[1])
print('-' * 20)
print("Test Loss: ", test_score[0])
print("Test Accuracy: ", test_score[1])
# Out:
# 1174/1174 [==============================] - 98s 83ms/step - loss: 0.0995 - accuracy: 0.9757
# 294/294 [==============================] - 24s 81ms/step - loss: 0.1845 - accuracy: 0.9517
# Train Loss:  0.09948386251926422
# Train Accuracy:  0.9756844639778137
# --------------------
# Test Loss:  0.18452133238315582
# Test Accuracy:  0.9517417550086975

# %%
y_pred = model.predict(X_test)
# Out:
# 294/294 [==============================] - 24s 81ms/step

# %%
y_pred = np.argmax(y_pred, axis=1)

# %%
y_true = Y_test.to_numpy()

# %%
from sklearn.metrics import accuracy_score, classification_report

# Assuming y_true is a NumPy array or a list and y_pred is a NumPy array
accuracy = accuracy_score(y_true, y_pred)
report = classification_report(y_true, y_pred)

# %%
print("Accuracy:", accuracy)
print("Classification Report:\n", report)
# Out:
# Accuracy: 0.9517417705337169
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      1359
#            1       0.97      1.00      0.99      1318
#            2       0.90      0.94      0.92      1262
#            3       0.99      1.00      1.00      1351
#            4       0.91      0.79      0.84      1374
#            5       0.99      1.00      1.00      1358
#            6       0.91      0.93      0.92      1365
#
#     accuracy                           0.95      9387
#    macro avg       0.95      0.95      0.95      9387
# weighted avg       0.95      0.95      0.95      9387

# %%
classes_labels = []
for key in classes.keys():
    classes_labels.append(key)

# %%
from sklearn.metrics import confusion_matrix
import itertools

# %%
# Confusion matrix
cm = cm = confusion_matrix(y_true, y_pred, labels=classes_labels)

plt.figure(figsize=(20,20))
plt.imshow(cm, interpolation= 'nearest', cmap= plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()

tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation= 45)
plt.yticks(tick_marks, classes)


thresh = cm.max() / 2.
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, cm[i, j], horizontalalignment= 'center', color= 'white' if cm[i, j] > thresh else 'black', fontsize=24)

plt.tight_layout()
plt.ylabel('True Label')
plt.xlabel('Predicted Label')

plt.show()
